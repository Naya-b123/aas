# %%
# Robot radius
robot_radius = 0.6

# Example obstacle boundary (simplified)
original_obstacle = 5  # arbitrary unit

# Inflate obstacle
inflated_obstacle = original_obstacle + robot_radius

# Output
print("Inflated Obstacle Size:", inflated_obstacle)
print("Result: Collision-Free Space")
# Out:
# Inflated Obstacle Size: 5.6
# Result: Collision-Free Space
