# %%
# Path costs
path_A = 6
path_B = 4

# Select minimum cost path
if path_A < path_B:
    best_path = "Path A"
else:
    best_path = "Path B"

# Output
print("Selected Path:", best_path)
# Out:
# Selected Path: Path B
