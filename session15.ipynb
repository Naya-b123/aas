# %%
# Input values
prediction = 20
measurement = 24

# Kalman update (simplified average)
estimate = (prediction + measurement) / 2

# Output
print("Estimated State:", estimate)
# Out:
# Estimated State: 22.0
