# %%
# Input condition
labeled_data = True

# Decision logic
if labeled_data:
    model_type = "Supervised Learning"
    algorithm = "Classification Model"
else:
    model_type = "Unsupervised Learning"
    algorithm = "Clustering Model"

# Output
print("Model Type:", model_type)
print("Selected Algorithm:", algorithm)
# Out:
# Model Type: Supervised Learning
# Selected Algorithm: Classification Model
