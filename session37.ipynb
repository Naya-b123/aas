# %%
# Waypoints list
waypoints = [1, 2, 3, 4, 5]

# Simulate continuous patrol (limited cycles for demo)
for _ in range(2):  # repeat twice
    for point in waypoints:
        print(f"Visiting Waypoint {point}")

print("Continuous Patrol")
# Out:
# Visiting Waypoint 1
# Visiting Waypoint 2
# Visiting Waypoint 3
# Visiting Waypoint 4
# Visiting Waypoint 5
# Visiting Waypoint 1
# Visiting Waypoint 2
# Visiting Waypoint 3
# Visiting Waypoint 4
# Visiting Waypoint 5
# Continuous Patrol
