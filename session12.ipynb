# %%
# Input values
similarity = 0.94
threshold = 0.9

# Place recognition logic
if similarity > threshold:
    recognized = True
    result = "Place Recognized"
else:
    recognized = False
    result = "Place Not Recognized"

# Output
print(result)
# Out:
# Place Recognized
